# %% [markdown]
# <a href="https://colab.research.google.com/github/inuwamobarak/document-summarization/blob/main/Wikipedia_Earth_Article_Summarization_Using%C2%A0Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Document Summarization on Wikipedia Articles Using Python

# %% [markdown]
# ## Importing/Installing Dependencies

# %%
# Backend
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4) (2.4)

# %%
pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (4.9.2)

# %%
# Core Libraries
import bs4 as bs
import urllib.request
import re

# Indirect requirements
import pandas as pd
import matplotlib.pyplot as plt
import io
import unicodedata
import numpy as np
import string

# %% [markdown]
# ## Fetching Articles from Wikipedia

# %%
# Scrapping the data and loading from url

wikipedia_article = urllib.request.urlopen('https://en.wikipedia.org/wiki/Earth')  # Open the URL which is the link to Wikipedia article on Earth
article = wikipedia_article.read() # Loading the content of article with all unwanted characters and tags

# %% [markdown]
# Find details on the urlib.request library here: https://docs.python.org/3/library/urllib.request.html

# %% [markdown]
# ## Preprocessing of the Data

# %%
parsed_article = bs.BeautifulSoup(article,'lxml') # BeautifulSoup lxml allows us to parse HTML and XML files

paragraphs = parsed_article.find_all('p') # Reads the <p> </p> tags in the article

article_text = ""

for p in paragraphs:
    article_text += p.text
    #article_text2 += p.

# %%
# Viewiing content with symbols
article_text
# Out:
# '\nLand: 148940000\xa0km2 (57510000\xa0sq\xa0mi) – 29.2%\nEarth is the third planet from the Sun and the only place known in the universe where life has originated and found habitability. While Earth may not contain the largest volumes of water in the Solar System, only Earth sustains liquid surface water, extending over 70.8% of the Earth with its ocean, making Earth an ocean world. Earth\'s polar regions currently retain most of all other water with large sheets of ice covering ocean and land, dwarfing Earth\'s groundwater, lakes, rivers and atmospheric water. Land, consisting of continents and islands, extends over 29.2% of the Earth and is widely covered by vegetation. Below Earth\'s surface material lies Earth\'s crust consisting of several slowly moving tectonic plates, which interact to produce mountain ranges, volcanoes, and earthquakes. Earth\'s liquid outer core generates a magnetic field that shapes the magnetosphere of Earth, largely deflecting destructive solar winds and cosmic radiation.\nEarth has an atmosphere, which sustains Earth\'s surface conditions and protects it from most meteoroids and UV-light at entry. It has a composition of primarily nitrogen and oxygen. Water vapor is widely present in the atmosphere, forming clouds that cover most of the planet. The water vapor, like the liquid surface water, mainly persists by traping together with other greenhouse gases in the atmosphere, particularly carbon dioxide (CO2), energy from the Sun\'s light, creating a crucial average surface temperature of currently 14.76\xa0°C. Differences in the amount of captured energy between geographic regions (as with the equatorial region receiving more sunlight than the polar regions) drive atmospheric and ocean currents, producing a global climate system with different climate regions, and a range of weather phenomena such as precipitation, allowing components such as nitrogen to cycle. \nEarth is rounded into an ellipsoid with a circumference of about 40,000\xa0km. It is the densest planet in the Solar System. Of the four rocky planets, it is the largest and most massive. Earth is about eight light-minutes away from the Sun and orbits it, taking a year (about 365.25 days) to complete one revolution. The Earth rotates around its own axis in slightly less than a day (in about 23 hours and 56 minutes). The Earth\'s axis of rotation is tilted with respect to the perpendicular to its orbital plane around the Sun, producing seasons. Earth is orbited by one permanent natural satellite, the Moon, which orbits Earth at 384,400\xa0km (1.28 light seconds) and is roughly a quarter as wide as Earth. Through tidal locking, the Moon always faces the Earth with the same side, which causes tides, stabilizes Earth\'s axis, and gradually slows its rotation.\nEarth, like most other bodies in the Solar System, formed 4.5 billion years ago from gas in the early Solar System. During the first billion years of Earth\'s history, the ocean formed and then life developed within it. Life spread globally and has been altering Earth\'s atmosphere and surface, leading to the Great Oxidation Event two billion years ago. Humans emerged 300,000 years ago, and have reached a population of 8 billion today. Humans depend on Earth\'s biosphere and natural resources for their survival, but have increasingly impacted the planet\'s environment. Humanity\'s current impact on Earth\'s climate and biosphere is unsustainable, threatening the livelihood of humans and many other life, causing widespread extinctions.[27]\nThe Modern English word  Earth developed, via Middle English, from an Old English noun most often spelled eorðe.[28] It has cognates in every Germanic language, and their ancestral root has been reconstructed as *erþō. In its earliest attestation, the word eorðe was already being used to translate the many senses of Latin terra and Greek γῆ gē: the ground, its soil, dry land, the human world, the surface of the world (including the sea), and the globe  ...

# %%
# Droping unwanted characters and spaces

article_text = re.sub(r'\[[0-9]*\]', ' ', article_text)
article_text = re.sub(r'\s+', ' ', article_text)
formatted_article_text = re.sub('[^a-zA-Z]', ' ', article_text )
formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)

# %%
# Viewing processed data without symbols
formatted_article_text
# Out:
# ' Land km sq mi Earth is the third planet from the Sun and the only place known in the universe where life has originated and found habitability While Earth may not contain the largest volumes of water in the Solar System only Earth sustains liquid surface water extending over of the Earth with its ocean making Earth an ocean world Earth s polar regions currently retain most of all other water with large sheets of ice covering ocean and land dwarfing Earth s groundwater lakes rivers and atmospheric water Land consisting of continents and islands extends over of the Earth and is widely covered by vegetation Below Earth s surface material lies Earth s crust consisting of several slowly moving tectonic plates which interact to produce mountain ranges volcanoes and earthquakes Earth s liquid outer core generates a magnetic field that shapes the magnetosphere of Earth largely deflecting destructive solar winds and cosmic radiation Earth has an atmosphere which sustains Earth s surface conditions and protects it from most meteoroids and UV light at entry It has a composition of primarily nitrogen and oxygen Water vapor is widely present in the atmosphere forming clouds that cover most of the planet The water vapor like the liquid surface water mainly persists by traping together with other greenhouse gases in the atmosphere particularly carbon dioxide CO energy from the Sun s light creating a crucial average surface temperature of currently C Differences in the amount of captured energy between geographic regions as with the equatorial region receiving more sunlight than the polar regions drive atmospheric and ocean currents producing a global climate system with different climate regions and a range of weather phenomena such as precipitation allowing components such as nitrogen to cycle Earth is rounded into an ellipsoid with a circumference of about km It is the densest planet in the Solar System Of the four rocky planets it is the largest and most massive Earth is about eight light minutes away from the Sun and orbits it taking a year about days to complete one revolution The Earth rotates around its own axis in slightly less than a day in about hours and minutes The Earth s axis of rotation is tilted with respect to the perpendicular to its orbital plane around the Sun producing seasons Earth is orbited by one permanent natural satellite the Moon which orbits Earth at km light seconds and is roughly a quarter as wide as Earth Through tidal locking the Moon always faces the Earth with the same side which causes tides stabilizes Earth s axis and gradually slows its rotation Earth like most other bodies in the Solar System formed billion years ago from gas in the early Solar System During the first billion years of Earth s history the ocean formed and then life developed within it Life spread globally and has been altering Earth s atmosphere and surface leading to the Great Oxidation Event two billion years ago Humans emerged years ago and have reached a population of billion today Humans depend on Earth s biosphere and natural resources for their survival but have increasingly impacted the planet s environment Humanity s current impact on Earth s climate and biosphere is unsustainable threatening the livelihood of humans and many other life causing widespread extinctions The Modern English word Earth developed via Middle English from an Old English noun most often spelled eor e It has cognates in every Germanic language and their ancestral root has been reconstructed as er In its earliest attestation the word eor e was already being used to translate the many senses of Latin terra and Greek g the ground its soil dry land the human world the surface of the world including the sea and the globe itself As with Roman Terra Tell s and Greek Gaia Earth may have been a personified goddess in Germanic paganism late Norse mythology included J r Earth a giantess often given as the mother of Thor Historically earth has been written in lowerc ...

# %% [markdown]
# ## Performing Text Tokenization

# %%
sentence_list = nltk.sent_tokenize(article_text) # Using NLTK and Punkt to generate tokens

# %%
sentence_list[:3] # Viewing few sentences
# Out:
# [' Land: 148940000 km2 (57510000 sq mi) – 29.2% Earth is the third planet from the Sun and the only place known in the universe where life has originated and found habitability.',
#  'While Earth may not contain the largest volumes of water in the Solar System, only Earth sustains liquid surface water, extending over 70.8% of the Earth with its ocean, making Earth an ocean world.',
#  "Earth's polar regions currently retain most of all other water with large sheets of ice covering ocean and land, dwarfing Earth's groundwater, lakes, rivers and atmospheric water."]

# %% [markdown]
# ## Weighting the Frequency of Words

# %%
stopwords = nltk.corpus.stopwords.words('english') # Loading the English version, you can change to other langages as required

# Iterating for individual words
word_frequencies = {}
for word in nltk.word_tokenize(formatted_article_text):
    if word not in stopwords: # Dodge stop words
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
maximum_frequncy = max(word_frequencies.values()) # Reading the number occurence of highest re-occuring word

# %%
maximum_frequncy
# Out:
# 255

# %%
most_frequent_word = max(word_frequencies) # Printing the highest re-occuring word

# %%
most_frequent_word
# Out:
# 'zone'

# %%
# Using the most occuring word as an avarage
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)

# %% [markdown]
# ## Finding the Score of Sentences

# %%
# We use the word frequency to measure the value of a sentence
sentence_scores = {}
for sent in sentence_list: # Reads article coontaining symbols
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys(): # Will ignore stop words in sentence_list
            if len(sent.split(' ')) < 32: # Dropping sentences with words more than 32. Summary should be short
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
# Viewing the value of each sentence
sentence_scores
# Out:
# {"Earth's polar regions currently retain most of all other water with large sheets of ice covering ocean and land, dwarfing Earth's groundwater, lakes, rivers and atmospheric water.": 1.0549019607843135,
#  'Land, consisting of continents and islands, extends over 29.2% of the Earth and is widely covered by vegetation.': 0.28235294117647053,
#  "Below Earth's surface material lies Earth's crust consisting of several slowly moving tectonic plates, which interact to produce mountain ranges, volcanoes, and earthquakes.": 0.6705882352941176,
#  "Earth's liquid outer core generates a magnetic field that shapes the magnetosphere of Earth, largely deflecting destructive solar winds and cosmic radiation.": 0.4627450980392156,
#  "Earth has an atmosphere, which sustains Earth's surface conditions and protects it from most meteoroids and UV-light at entry.": 0.48235294117647054,
#  'It has a composition of primarily nitrogen and oxygen.': 0.09019607843137255,
#  'Water vapor is widely present in the atmosphere, forming clouds that cover most of the planet.': 0.5254901960784314,
#  'Earth is rounded into an ellipsoid with a circumference of about 40,000 km.': 0.16862745098039217,
#  'It is the densest planet in the Solar System.': 0.19607843137254902,
#  'Of the four rocky planets, it is the largest and most massive.': 0.10196078431372549,
#  'Earth is about eight light-minutes away from the Sun and orbits it, taking a year (about 365.25 days) to complete one revolution.': 0.25098039215686274,
#  'The Earth rotates around its own axis in slightly less than a day (in about 23 hours and 56 minutes).': 0.28627450980392155,
#  "The Earth's axis of rotation is tilted with respect to the perpendicular to its orbital plane around the Sun, producing seasons.": 0.26274509803921564,
#  'Earth is orbited by one permanent natural satellite, the Moon, which orbits Earth at 384,400 km (1.28 light seconds) and is roughly a quarter as wide as Earth.': 0.40784313725490196,
#  "Through tidal locking, the Moon always faces the Earth with the same side, which causes tides, stabilizes Earth's axis, and gradually slows its rotation.": 0.2549019607843137,
#  'Earth, like most other bodies in the Solar System, formed 4.5 billion years ago from gas in the early Solar System.': 0.6901960784313725,
#  "During the first billion years of Earth's history, the ocean formed and then life developed within it.": 0.6784313725490195,
#  "Life spread globally and has been altering Earth's atmosphere and surface, leading to the Great Oxidation Event two billion years ago.": 0.8823529411764706,
#  'Humans emerged 300,000 years ago, and have reached a population of 8 billion today.': 0.33333333333333326,
#  "Humans depend on Earth's biosphere and natural resources for their survival, but have increasingly impacted the planet's environment.": 0.25882352941176473,
#  "Humanity's current impact on Earth's climate and biosphere is unsustainable, threatening the livelihood of humans and many other life, causing widespread extinctions.": 0.44705882352941173,
#  'The Modern English word Earth developed, via Middle English, from an Old English noun most often spelled eorðe.': 0.14509803921568626,
#  'It has cognates in every Germanic language, and their ancestral root has been reconstructed as *erþō.': 0.054901960784313725,
#  'Historically, earth has been written in lowercase.': 0.047058823529411764,
#  'From early Middle English, its definite sense as "the globe" was expressed as the earth.': 0.10588235294117647,
#  'By the era of Early Modern English, capitalization of nouns began to prevail, and the earth was also written the Earth, particularly when referenced along with other heavenly bodies.': 0.30980392156862735,
#  'More recently, the name is sometimes simply given as Earth, by analogy with the names of the other planets, though earth and forms with the remain common.': 0.2196078431372549,
#  'House styles now vary: Oxford spelling recognizes the lowercase form as the most common, with the capitalized form an acceptable variant.': 0.196078431372549,
#  'Another convention capitalizes "Earth" when appearing as a name (for example, "Earth\'s atmosphere") but writes it in lowercase when preceded by the (for example, "the atmosphere of the earth").': 0.47058823529411764,
#  'It almost always appears in lowercase in colloquial expressions such as "what on earth are you doing?"': 0.07450980392156863,
#  'There are a number of adjectives for the planet Earth.': 0.10196078431372549,
#  'From Earth itself comes earthly.': 0.043137254901960784,
#  'From the Latin Terra comes terran /ˈtɛrən/, terrestrial /təˈrɛstriəl/, and (via French) terrene /təˈriːn/, and from the Latin Tellus comes tellurian /tɛˈlʊəriən/ and telluric.': 0.07450980392156863,
#  'The oldest material found in the Solar System is dated to 4.5682+0.0002−0.0004 Ga (billion years) ago.': 0.43529411764705883,
#  'By 4.54±0.04 Ga the primordial Earth had formed.': 0.10588235294117647,
#  'The bodies in the Solar System formed and evolved with the Sun.': 0.2549019607843137,
#  'A nebula contains gas, ice grains, and dust (including primordial nuclides).': 0.16862745098039217,
#  'According to nebular theory, planetesimals formed by accretion, with the primordial Earth being estimated as likely taking anywhere from 70 to 100 million years to form.': 0.49411764705882355,
#  'Estimates of the age of the Moon range from 4.5 Ga to significantly younger.': 0.06666666666666667,
#  'It hit Earth with a glancing blow and some of its mass merged with Earth.': 0.12156862745098039,
#  "Earth's atmosphere and oceans were formed by volcanic activity and outgassing.": 0.3686274509803921,
#  'Water vapor from these sources condensed into the oceans, augmented by water and ice from asteroids, protoplanets, and comets.': 0.5999999999999999,
#  'Sufficient water to fill the oceans may have been on Earth since it formed.': 0.4392156862745098,
#  'In this model, atmospheric greenhouse gases kept the oceans from freezing when the newly forming Sun had only 70% of its current luminosity.': 0.2862745098039216,
#  "By 3.5 Ga, Earth's magnetic field was established, which helped prevent the atmosphere from being stripped away by the solar wind.": 0.45490196078431366,
#  'As the molten outer layer of Earth cooled it formed the first solid crust, which is thought to have been mafic in composition.': 0.4313725490196078,
#  'The first continental crust, which was more felsic in composition, formed by the partial melting of this mafic crust.': 0.48627450980392156,
#  "The two models and the data that support them can be reconciled by large-scale recycling of the continental crust, particularly during the early stages of Earth's history.": 0.396078431372549,
#  "New continental crust forms as a result of plate tectonics, a process ultimately driven by the continuous loss of heat from Earth's interior.": 0.4666666666666667,
#  'Over the period of hundreds of millions of years, tectonic forces have caused areas of continental crust to group together to form supercontinents that have subsequently broken apart.': 0.5999999999999999,
#  'At approximately 750 Ma, one of the earliest known supercontinents, Rodinia, began to break apart.': 0.19215686274509802,
#  'The continents later recombined to form Pannotia at 600–540 Ma, then finally Pangaea, which also began to break apart at 180 Ma.': 0.21176470588235294,
#  'The most recent pattern of ice ages began about 40 Ma, and then intensified during the Pleistocene about 3 Ma.': 0.12941176470588234,
#  'High- and middle-latitude regions have since undergone repeated cycles of glaciation and thaw, repeating about every 21,000, 41,000 and 100,000 years.': 0.26666666666666666,
#  'The Last Glacial Period, colloquially called the "last ice age", covered large parts of the continents, to the middle latitudes, in ice and ended about 11,700 years ago.': 0.6117647058823529,
#  'Chemical reactions led to the first self-replicating molecules about four billion years ago.': 0.32941176470588235,
#  'A half billion years later, the last common ancestor of all current life arose.': 0.4235294117647059,
#  "The evolution of photosynthesis allowed the Sun's energy to be harvested directly by life forms.": 0.26666666666666666,
#  'The resultant molecular oxygen (O2) accumulated in the atmosphere and due to interaction with ultraviolet solar radiation, formed a protective ozone layer (O3) in the upper atmosphere.': 0.7411764705882353,
#  'The incorporation of smaller cells within larger ones resulted in the development of complex cells called eukaryotes.': 0.196078431372549,
#  'True multicellular organisms formed as cells within colonies became increasingly specialized.': 0.19999999999999996,
#  "Aided by the absorption of harmful ultraviolet radiation by the ozone layer, life colonized Earth's surface.": 0.5058823529411764,
#  'The earliest direct evidence of life on Earth is contained in 3.45 billion-year-old Australian rocks showing fossils of microorganisms.': 0.24705882352941178,
#  'During the Neoproterozoic, 1000 to 539 Ma, much of Earth might have been covered in ice.': 0.16862745098039217,
#  'This hypothesis has been termed "Snowball Earth", and it is of particular interest because it preceded the Cambrian explosion, when multicellular life forms significantly increased in complexity.': 0.2823529411764706,
#  'Following the Cambrian explosion, 535 Ma, there have been at least five major mass extinctions and many minor ones.': 0.18431372549019606,
#  'Mammalian life has diversified over the past 66 Mys, and several million years ago an African ape species gained the ability to stand upright.': 0.4980392156862744,
#  '[better source needed] This facilitated tool use and encouraged communication that provided the nutrition and stimulation needed for a larger brain, which led to the evolution of humans.': 0.16862745098039217,
#  'The development of agriculture, and then civilization, led to humans having an influence on Earth and the nature and quantity of other life forms that continues to this day.': 0.3647058823529411,
#  "Earth's expected long-term future is tied to that of the Sun.": 0.047058823529411764,
#  'Over the next 1.1 billion years, solar luminosity will increase by 10%, and over the next 3.5 billion years by 40%.': 0.5333333333333333,
#  "Earth's increasing surface temperature will accelerate the inorganic carbon cycle, reducing CO2 concentration to levels lethally low for plants (10 ppm for C4 photosynthesis) in approximately 100–900 million years.": 0.8039215686274508,
#  'The lack of vegetation will result in the loss of oxygen in the atmosphere, making animal life impossible.': 0.4352941176470588,
#  'Even if the Sun were stable, a fraction of the water in the modern oceans will descend to the mantle, due to reduced steam venting from mid-ocean ridges.': 0.4352941176470588,
#  'The Sun will evolve to become a red giant in about 5 billion years.': 0.2392156862745098,
#  'Models predict that the Sun will expand to roughly 1 AU (150 million km; 93 million mi), about 250 times its present radius.': 0.6352941176470589,
#  "Earth's fate is less clear.": 0.058823529411764705,
#  "Earth's shape furthermore has local topographic variations.": 0.09019607843137255,
#  'Parallel to the rigid land topography the Ocean exhibits a more dynamic topography.': 0.3294117647058823,
#  "To measure the local variation of Earth's topography, geodesy employs an idealized Earth producing a shape called a geoid.": 0.21176470588235297,
#  'Such a geoid shape is gained if the ocean is idealized, covering Earth completely and without any perturbations such as tides and winds.': 0.2705882352941177,
#  'The result is a smooth but gravitational irregular geoid surface, providing a mean sea level (MSL) as a reference level for topographic measurements.': 0.5294117647058822,
#  "Earth's surface is the top layer of Earth's rigid or liquid structure, at the interface with its atmosphere.": 0.5843137254901961,
#  'Earth as an idealized spheroid has a surface area of about 510 million km2 (197 million sq mi).': 0.7372549019607842,
#  'Earth can be divided into two hemispheres.': 0.11764705882352941,
#  'Generally, Earth is divided by latitude into the polar Northern and Southern hemispheres, or by longitude into the continental Eastern and Western hemispheres.': 0.2588235294117647,
#  'Regarding the surface distribution of land and water, Earth can be divided into an oceans-focused water hemisphere and a landmasses-focused land hemisphere.': 0.968627450980392,
#  "Most of Earth's surface is made of water, in liquid form or in smaller amounts as ice.": 0.6745098039215687,
#  "70.8% or 361.13 million km2 (139.43 million sq mi) of Earth's surface consists of the interconnected ocean, making it Earth's global ocean or world ocean.": 1.254901960784314,
#  'The world ocean is commonly divided into the Pacific Ocean, Atlantic Ocean, Indian Ocean, Southern Ocean, and Arctic Ocean, from largest to smallest.': 0.9215686274509803,
#  'The ocean fills the oceanic basins.': 0.1843137254901961,
#  'The ocean floor comprises abyssal plains, continental shelves, seamounts, submarine volcanoes, oceanic trenches, submarine canyons, oceanic plateaus, and a globe-spanning mid-ocean ridge system.': 0.39607843137254906,
#  "Earth's land is 29.2%, or 148.94 million km2 (57.51 million sq mi) of Earth's surface area.": 0.8705882352941177,
#  "Earth's land consists of many islands around the globe, but mainly of four continental landmasses, which are, from largest to smallest: Africa-Eurasia, America (landmass), Antarctica, and Australia (landmass).": 0.4745098039215685,
#  'These landmasses are further broken down and grouped into the continents.': 0.047058823529411764,
#  'The terrain varies greatly and consists of mountains, deserts, plains, plateaus, and other landforms.': 0.1372549019607843,
#  'The mean height of land above sea level is about 797 m (2,615 ft).': 0.3058823529411765,
#  'Land can be covered by surface water, snow, ice, artificial structures or vegetation.': 0.7098039215686275,
#  "The pedosphere is the outermost layer of Earth's continental surface and is composed of soil and subject to soil formation processes.": 0.5215686274509804,
#  'Soil is crucial for land to be arable.': 0.16470588235294117,
#  "Earth's total arable land is 10.7% of the land surface, with 1.3% being permanent cropland.": 0.5529411764705882,
#  'Earth has an estimated 16.7 million km2 (6.4 million sq mi) of cropland and 33.5 million km2 (12.9 million sq mi) of pastureland.': 0.9450980392156861,
#  "The pedosphere and the ocean, with its ocean floor, rest on Earth's crust, which together with parts of the upper mantle form Earth's lithosphere.": 0.6901960784313725,
#  "Earth's crust is divided into oceanic and continental crusts, while the latter consists of lower density material such as the igneous rocks granite and andesite.": 0.4862745098039215,
#  'Basalt, a denser volcanic rock primarily constitutes the lithosphere of the ocean floors.': 0.2431372549019608,
#  "Earth's surface topography consists mostly of the topography of the ocean surface and to a lesser extend of the terrain of Earth's crust above sea level.": 0.9921568627450982,
#  'Sedimentary rock is formed from the accumulation of sediment that becomes buried and compacted together.': 0.16470588235294117,
#  'Nearly 75% of the continental surfaces are covered by sedimentary rocks, although they form about 5% of the crust.': 0.3843137254901961,
#  'The third form of rock material found on Earth is metamorphic rock, which is created from the transformation of pre-existing rock types through high pressures, high temperatures, or both.': 0.30196078431372547,
#  "The most abundant silicate minerals on Earth's surface include quartz, feldspars, amphibole, mica, pyroxene and olivine.": 0.3294117647058823,
#  'Common carbonate minerals include calcite (found in limestone) and dolomite.': 0.10196078431372549,
#  "Earth's mechanically rigid outer layer of Earth's crust and upper mantle, the lithosphere, is divided into tectonic plates.": 0.5529411764705883,
#  'Along these plate boundaries, earthquakes, volcanic activity, mountain-building, and oceanic trench formation can occur.': 0.2196078431372549,
#  'The tectonic plates ride on top of the asthenosphere, the solid but less-viscous part of the upper mantle that can flow and move along with the plates.': 0.3647058823529412,
#  'As the tectonic plates migrate, oceanic crust is subducted under the leading edges of the plates at convergent boundaries.': 0.41960784313725485,
#  'At the same time, the upwelling of mantle material at divergent boundaries creates mid-ocean ridges.': 0.2196078431372549,
#  'The combination of these processes recycles the oceanic crust back into the mantle.': 0.2784313725490196,
#  'Due to this recycling, most of the ocean floor is less than 100 Ma old.': 0.25490196078431376,
#  'The oldest oceanic crust is located in the Western Pacific and is estimated to be 200 Ma old.': 0.25882352941176473,
#  'The seven major plates are the Pacific, North American, Eurasian, African, Antarctic, Indo-Australian, and South American.': 0.09803921568627451,
#  'Other notable plates include the Arabian Plate, the Caribbean Plate, the Nazca Plate off the west coast of South America and the Scotia Plate in the southern Atlantic Ocean.': 0.32156862745098036,
#  'The Australian Plate fused with the Indian Plate between 50 and 55 Ma.': 0.050980392156862744,
#  'The fastest-moving plates are the oceanic plates, with the Cocos Plate advancing at a rate of 75 mm/a (3.0 in/year) and the Pacific Plate moving 52–69 mm/a (2.0–2.7 in/year).': 0.2784313725490196,
#  'At the other extreme, the slowest-moving plate is the South American Plate, progressing at a typical rate of 10.6 mm/a (0.42 in/year).': 0.09411764705882353,
#  "Earth's interior, like that of the other terrestrial planets, is divided into layers by their chemical or physical (rheological) properties.": 0.18823529411764706,
#  'The outer layer is a chemically distinct silicate solid crust, which is underlain by a highly viscous solid mantle.': 0.38431372549019605,
#  'The crust is separated from the mantle by the Mohorovičić discontinuity.': 0.21176470588235297,
#  'The thickness of the crust varies from about 6 kilometers (3.7 mi) under the oceans to 30–50 km (19–31 mi) for the continents.': 0.6509803921568628,
#  'The crust and the cold, rigid, top of the upper mantle are collectively known as the lithosphere, which is divided into independently moving tectonic plates.': 0.5058823529411764,
#  'Beneath the lithosphere is the asthenosphere, a relatively low-viscosity layer on which the lithosphere rides.': 0.14509803921568626,
#  'Beneath the mantle, an extremely low viscosity liquid outer core lies above a solid inner core.': 0.3176470588235294,
#  'The radius of the inner core is about one-fifth of that of Earth.': 0.10196078431372549,
#  'Density increases with depth, as described in the table on the right.': 0.054901960784313725,
#  "Among the Solar System's planetary-sized objects Earth is the object with the highest density.": 0.20392156862745098,
#  "Earth's mass is approximately 5.97×1024 kg (5,970 Yg).": 0.1411764705882353,
#  'Due to gravitational separation, the core is primarily composed of the denser elements: iron (88.8%), with smaller amounts of nickel (5.8%), sulfur (4.5%), and less than 1% trace elements.': 0.32156862745098036,
#  'The most common rock constituents of the crust are oxides.': 0.207843137254902,
#  'Over 99% of the crust is composed of various oxides of eleven elements, principally oxides containing silicon (the silicate minerals), aluminum, iron, calcium, magnesium, potassium, or sodium.': 0.3019607843137254,
#  'The major heat-producing isotopes within Earth are potassium-40, uranium-238, and thorium-232.': 0.11764705882352941,
#  'At the center, the temperature may be up to 6,000 °C (10,830 °F), and the pressure could reach 360 GPa (52 million psi).': 0.30980392156862746,
#  'These plumes can produce hotspots and flood basalts.': 0.027450980392156862,
#  'More of the heat in Earth is lost through plate tectonics, by mantle upwelling associated with mid-ocean ridges.': 0.21568627450980393,
#  'The gravity of Earth is the acceleration that is imparted to objects due to the distribution of mass within Earth.': 0.27450980392156865,
#  "Near Earth's surface, gravitational acceleration is approximately 9.8 m/s2 (32 ft/s2).": 0.37254901960784315,
#  "Local differences in topography, geology, and deeper tectonic structure cause local and broad regional differences in Earth's gravitational field, known as gravity anomalies.": 0.33725490196078434,
#  "The field extends outwards from the core, through the mantle, and up to Earth's surface, where it is, approximately, a dipole.": 0.5137254901960784,
#  "The poles of the dipole are located close to Earth's geographic poles.": 0.12549019607843137,
#  'The convection movements in the core are chaotic; the magnetic poles drift and periodically change alignment.': 0.18823529411764706,
#  'This causes secular variation of the main field and field reversals at irregular intervals averaging a few times every million years.': 0.5294117647058824,
#  'The most recent reversal occurred approximately 700,000 years ago.': 0.23137254901960785,
#  "The extent of Earth's magnetic field in space defines the magnetosphere.": 0.2156862745098039,
#  'Charged particles are contained within the magnetosphere; the plasmasphere is defined by low-energy particles that essentially follow magnetic field lines as Earth rotates.': 0.34509803921568627,
#  "Earth's rotation period relative to the Sun—its mean solar day—is 86,400 seconds of mean solar time (86,400.0025 SI seconds).": 0.5215686274509803,
#  'Earth orbits the Sun, making Earth the third-closest planet to the Sun and part of the inner Solar System.': 0.34509803921568627,
#  'Earth orbits the Sun every 365.2564 mean solar days, or one sidereal year.': 0.40392156862745093,
#  "With an apparent movement of the Sun in Earth's sky at a rate of about 1°/day eastward, which is one apparent Sun or Moon diameter every 12 hours.": 0.2784313725490196,
#  'Due to this motion, on average it takes 24 hours—a solar day—for Earth to complete a full rotation about its axis so that the Sun returns to the meridian.': 0.35686274509803917,
#  'The Moon and Earth orbit a common barycenter every 27.32 days relative to the background stars.': 0.21960784313725487,
#  "When combined with the Earth-Moon system's common orbit around the Sun, the period of the synodic month, from new moon to new moon, is 29.53 days.": 0.2705882352941177,
#  'Viewed from the celestial north pole, the motion of Earth, the Moon, and their axial rotations are all counterclockwise.': 0.1450980392156863,
#  "Viewed from a vantage point above the Sun and Earth's north poles, Earth orbits in a counterclockwise direction about the Sun.": 0.17647058823529413,
#  'Without this tilt, there would be an eclipse every two weeks, alternating between lunar eclipses and solar eclipses.': 0.28627450980392155,
#  'The Hill sphere, or the sphere of gravitational influence, of Earth is about 1.5 million km (930,000 mi) in radius.': 0.5098039215686275,
#  "[n 11] This is the maximum distance at which Earth's gravitational influence is stronger than the more distant Sun and planets.": 0.21568627450980393,
#  'Objects must orbit Earth within this radius, or they can become unbound by the gravitational perturbation of the Sun.': 0.24313725490196073,
#  'Earth, along with the Solar System, is situated in the Milky Way and orbits about 28,000 light-years from its center.': 0.2196078431372549,
#  'It is about 20 light-years above the galactic plane in the Orion Arm.': 0.027450980392156862,
#  'The axial tilt of Earth is approximately 23.439281° with the axis of its orbit plane, always pointing towards the Celestial Poles.': 0.32156862745098036,
#  "Due to Earth's axial tilt, the amount of sunlight reaching any given point on the surface varies over the course of the year.": 0.5803921568627451,
#  'In each instance, winter occurs simultaneously in the opposite hemisphere.': 0.058823529411764705,
#  'During the summer, the day lasts longer, and the Sun climbs higher in the sky.': 0.16078431372549018,
#  'In winter, the climate becomes cooler and the days shorter.': 0.12156862745098039,
#  'These same latitudes also experience a midnight sun, where the sun remains visible all day.': 0.2156862745098039,
#  'In the Southern Hemisphere, the situation is reversed, with the summer and winter solstices exchanged and the spring and autumnal equinox dates swapped.': 0.11372549019607843,
#  "The angle of Earth's axial tilt is relatively stable over long periods of time.": 0.2274509803921569,
#  'Its axial tilt does undergo nutation; a slight, irregular motion with a main period of 18.6 years.': 0.29411764705882354,
#  "Both of these motions are caused by the varying attraction of the Sun and the Moon on Earth's equatorial bulge.": 0.12156862745098039,
#  "The poles also migrate a few meters across Earth's surface.": 0.396078431372549,
#  'This polar motion has multiple, cyclical components, which collectively are termed quasiperiodic motion.': 0.16078431372549018,
#  'In addition to an annual component to this motion, there is a 14-month cycle called the Chandler wobble.': 0.10980392156862745,
#  "Earth's rotational velocity also varies in a phenomenon known as length-of-day variation.": 0.21960784313725487,
#  "In modern times, Earth's perihelion occurs around 3 January, and its aphelion around 4 July.": 0.20784313725490194,
#  'These dates change over time due to precession and other orbital factors, which follow cyclical patterns known as Milankovitch cycles.': 0.2588235294117647,
#  'The changing Earth-Sun distance causes an increase of about 6.8% in solar energy reaching Earth at perihelion relative to aphelion.': 0.3490196078431371,
#  "The Moon is a relatively large, terrestrial, planet-like natural satellite, with a diameter about one-quarter of the Earth's.": 0.1843137254901961,
#  'It is the largest moon in the Solar System relative to the size of its planet, although Charon is larger relative to the dwarf planet Pluto.': 0.44705882352941173,
#  'The natural satellites of other planets are also referred to as "moons", after Earth\'s.': 0.19215686274509802,
#  "The most widely accepted theory of the Moon's origin, the giant-impact hypothesis, states that it formed from the collision of a Mars-size protoplanet called Theia with the early Earth.": 0.2588235294117647,
#  "This hypothesis explains (among other things) the Moon's relative lack of iron and volatile elements and the fact that its composition is nearly identical to that of Earth's crust.": 0.3411764705882353,
#  'The gravitational attraction between Earth and the Moon causes tides on Earth.': 0.1411764705882353,
#  'The same effect on the Moon has led to its tidal locking: its rotation period is the same as the time it takes to orbit Earth.': 0.28627450980392155,
#  'As a result, it always presents the same face to the planet.': 0.12156862745098039,
#  'As the Moon orbits Earth, different parts of its face are illuminated by the Sun, leading to the lunar phases.': 0.1647058823529412,
#  'Due to their tidal interaction, the Moon recedes from Earth at the rate of approximately 38 mm/a (1.5 in/year).': 0.20784313725490197,
#  "Over millions of years, these tiny modifications—and the lengthening of Earth's day by about 23 µs/yr—add up to significant changes.": 0.2901960784313726,
#  'During the Ediacaran period, for example, (approximately 620 Ma) there were 400±7 days in a year, with each day lasting 21.9±0.4 hours.': 0.2980392156862745,
#  "The Moon may have dramatically affected the development of life by moderating the planet's climate.": 0.33333333333333337,
#  "Paleontological evidence and computer simulations show that Earth's axial tilt is stabilized by tidal interactions with the Moon.": 0.16862745098039217,
#  'Viewed from Earth, the Moon is just far enough away to have almost the same apparent-sized disk as the Sun.': 0.09411764705882353,
#  'This allows total and annular solar eclipses to occur on Earth.': 0.16862745098039214,
#  "Earth's co-orbital asteroids population consists of quasi-satellites, objects with a horseshoe orbit and trojans.": 0.14901960784313723,
#  'There are at least five quasi-satellites, including 469219 Kamoʻoalewa.': 0.06666666666666667,
#  "A trojan asteroid companion, 2010 TK7, is librating around the leading Lagrange triangular point, L4, in Earth's orbit around the Sun.": 0.2784313725490196,
#  'The tiny near-Earth asteroid 2006 RH120 makes close approaches to the Earth–Moon system roughly every twenty years.': 0.25882352941176473,
#  'During these approaches, it can orbit Earth for brief periods of time.': 0.15294117647058825,
#  'As of September 2021[update], there are 4,550 operational, human-made satellites orbiting Earth.': 0.06274509803921569,
#  'There are also inoperative satellites, including Vanguard 1, the oldest satellite currently in orbit, and over 16,000 pieces of tracked space debris.': 0.27450980392156854,
#  "[n 3] Earth's largest artificial satellite is the International Space Station.": 0.1568627450980392,
#  "Earth's hydrosphere is the sum of Earth's water and its distribution.": 0.27058823529411763,
#  "Most of Earth's hydrosphere consists of Earth's global ocean.": 0.2549019607843137,
#  "The mass of the oceans is approximately 1.35×1018 metric tons or about 1/4400 of Earth's total mass.": 0.2941176470588235,
#  'About 97.5% of the water is saline; the remaining 2.5% is fresh water.': 0.4117647058823529,
#  'Most fresh water, about 68.7%, is present as ice in ice caps and glaciers.': 0.4274509803921569,
#  "In Earth's coldest regions, snow survives over the summer and changes into ice.": 0.23137254901960783,
#  'This accumulated snow and ice eventually forms into glaciers, bodies of ice that flow under the influence of their own gravity.': 0.34117647058823525,
#  'Alpine glaciers form in mountainous areas, whereas vast ice sheets form over land in polar regions.': 0.5372549019607844,
#  'The flow of glaciers erodes the surface changing it dramatically, with the formation of U-shaped valleys and other landforms.': 0.3254901960784313,
#  'Sea ice in the Arctic covers an area about as big as the United States, although it is quickly retreating as a consequence of climate change.': 0.30588235294117644,
#  "The average salinity of Earth's oceans is about 35 grams of salt per kilogram of seawater (3.5% salt).": 0.21176470588235297,
#  'Most of this salt was released from volcanic activity or extracted from cool igneous rocks.': 0.12156862745098039,
#  'The oceans are also a reservoir of dissolved atmospheric gases, which are essential for the survival of many aquatic life forms.': 0.45490196078431366,
#  "Sea water has an important influence on the world's climate, with the oceans acting as a large heat reservoir.": 0.584313725490196,
#  'Shifts in the oceanic temperature distribution can cause significant weather shifts, such as the El Niño–Southern Oscillation.': 0.19215686274509805,
#  "The abundance of water, particularly liquid water, on Earth's surface is a unique feature that distinguishes it from other planets in the Solar System.": 0.8901960784313725,
#  'Solar System planets with considerable atmospheres do partly host atmospheric water vapor, but they lack surface conditions for stable surface water.': 1.1686274509803922,
#  "The atmospheric pressure at Earth's sea level averages 101.325 kPa (14.696 psi), with a scale height of about 8.5 km (5.3 mi).": 0.4627450980392157,
#  'A dry atmosphere is composed of 78.084% nitrogen, 20.946% oxygen, 0.934% argon, and trace amounts of carbon dioxide and other gaseous molecules.': 0.3333333333333333,
#  'Water vapor content varies between 0.01% and 4% but averages about 1%.': 0.2784313725490196,
#  "Clouds cover around two thirds of Earth's surface, more so over oceans than land.": 0.5882352941176471,
#  "Earth's biosphere has significantly altered its atmosphere.": 0.2274509803921569,
#  'Oxygenic photosynthesis evolved 2.7 Gya, forming the primarily nitrogen–oxygen atmosphere of today.': 0.2392156862745098,
#  'This change enabled the proliferation of aerobic organisms and, indirectly, the formation of the ozone layer due to the subsequent conversion of atmospheric O2 into O3.': 0.26274509803921564,
#  'The ozone layer blocks ultraviolet solar radiation, permitting life on land.': 0.46274509803921565,
#  'Other atmospheric functions important to life include transporting water vapor, providing useful gases, causing small meteors to burn up before they strike the surface, and moderating temperature.': 0.8549019607843137,
#  'This last phenomenon is the greenhouse effect: trace molecules within the atmosphere serve to capture thermal energy emitted from the surface, thereby raising the average temperature.': 0.807843137254902,
#  'Water vapor, carbon dioxide, methane, nitrous oxide, and ozone are the primary greenhouse gases in the atmosphere.': 0.5176470588235293,
#  "Earth's atmosphere has no definite boundary, gradually becoming thinner and fading into outer space.": 0.29803921568627445,
#  "Three-quarters of the atmosphere's mass is contained within the first 11 km (6.8 mi) of the surface; this lowest layer is called the troposphere.": 0.9137254901960785,
#  'Energy from the Sun heats this layer, and the surface below, causing expansion of the air.': 0.4509803921568628,
#  'This lower-density air then rises and is replaced by cooler, higher-density air.': 0.07058823529411765,
#  'The result is atmospheric circulation that drives the weather and climate through redistribution of thermal energy.': 0.2823529411764706,
#  'The primary atmospheric circulation bands consist of the trade winds in the equatorial region below 30° latitude and the westerlies in the mid-latitudes between 30° and 60°.': 0.18823529411764706,
#  'Ocean heat content and currents are also important factors in determining climate, particularly the thermohaline circulation that distributes thermal energy from the equatorial oceans to the polar regions.': 0.7529411764705882,
#  'Earth receives 1361 W/m2 of solar irradiance.': 0.1333333333333333,
#  "The amount of solar energy that reaches the Earth's surface decreases with increasing latitude.": 0.5333333333333333,
#  'At higher latitudes, the sunlight reaches the surface at lower angles, and it must pass through thicker columns of the atmosphere.': 0.5254901960784313,
#  'As a result, the mean annual air temperature at sea level decreases by about 0.4 °C (0.7 °F) per degree of latitude from the equator.': 0.34901960784313724,
#  "Earth's surface can be subdivided into specific latitudinal belts of approximately homogeneous climate.": 0.403921568627451,
#  'Ranging from the equator to the polar regions, these are the tropical (or equatorial), subtropical, temperate and polar climates.': 0.25098039215686274,
#  "Further factors that affect a location's climates are its proximity to oceans, the oceanic and atmospheric circulation, and topology.": 0.23529411764705882,
#  'Places close to oceans typically have colder summers and warmer winters, due to the fact that oceans can store large amounts of heat.': 0.3882352941176471,
#  'The wind transports the cold or the heat of the ocean to the land.': 0.3686274509803922,
#  'Atmospheric circulation also plays an important role: San Francisco and Washington DC are both coastal cities at about the same latitude.': 0.2117647058823529,
#  "San Francisco's climate is significantly more moderate as the prevailing wind direction is from sea to land.": 0.30980392156862746,
#  'Finally, temperatures decrease with height causing mountainous areas to be colder than low-lying areas.': 0.1764705882352941,
#  'Water vapor generated through surface evaporation is transported by circulatory patterns in the atmosphere.': 0.6549019607843137,
#  'When atmospheric conditions permit an uplift of warm, humid air, this water condenses and falls to the surface as precipitation.': 0.584313725490196,
#  'Most of the water is then transported to lower elevations by river systems and usually returned to the oceans or deposited into lakes.': 0.3411764705882353,
#  'This water cycle is a vital mechanism for supporting life on land and is a primary factor in the erosion of surface features over geological periods.': 0.7725490196078431,
#  'Precipitation patterns vary widely, ranging from several meters of water per year to less than a millimeter.': 0.4196078431372549,
#  'Atmospheric circulation, topographic features, and temperature differences determine the average precipitation that falls in each region.': 0.2627450980392157,
#  'The commonly used Köppen climate classification system has five broad groups (humid tropics, arid, humid middle latitudes, continental and cold polar), which are further divided into more specific subtypes.': 0.4235294117647058,
#  'The Köppen system rates regions based on observed temperature and precipitation.': 0.1803921568627451,
#  'The upper atmosphere, the atmosphere above the troposphere, is usually divided into the stratosphere, mesosphere, and thermosphere.': 0.4117647058823529,
#  'Each layer has a different lapse rate, defining the rate of change in temperature with height.': 0.2745098039215686,
#  'Beyond these, the exosphere thins out into the magnetosphere, where the geomagnetic fields interact with the solar wind.': 0.21176470588235294,
#  'Within the stratosphere is the ozone layer, a component that partially shields the surface from ultraviolet light and thus is important for life on Earth.': 0.6235294117647059,
#  "The Kármán line, defined as 100 km (62 mi) above Earth's surface, is a working definition for the boundary between the atmosphere and outer space.": 0.7686274509803921,
#  "Thermal energy causes some of the molecules at the outer edge of the atmosphere to increase their velocity to the point where they can escape from Earth's gravity.": 0.4549019607843137,
#  'This causes a slow but steady loss of the atmosphere into space.': 0.2705882352941177,
#  'Because unfixed hydrogen has a low molecular mass, it can achieve escape velocity more readily, and it leaks into outer space at a greater rate than other gases.': 0.3333333333333333,
#  "The leakage of hydrogen into space contributes to the shifting of Earth's atmosphere and surface from an initially reducing state to its current oxidizing one.": 0.5960784313725489,
#  'Hence the ability of hydrogen to escape from the atmosphere may have influenced the nature of life that developed on Earth.': 0.4274509803921568,
#  'In the current, oxygen-rich atmosphere most hydrogen is converted into water before it has an opportunity to escape.': 0.42745098039215684,
#  'Instead, most of the hydrogen loss comes from the destruction of methane in the upper atmosphere.': 0.2784313725490196,
#  'Earth is the only known place that was and has been habitable for life.': 0.18823529411764706,
#  "Earth's life developed in Earth's early bodies of water some hundred million years after Earth formed.": 0.819607843137255,
#  "Earth's life has been shaping and inhabiting many particular ecosystems on Earth and has eventually expanded globally forming an overarching biosphere.": 0.3176470588235294,
#  "Therefore, life has impacted Earth, significantly altering Earth's atmosphere and surface over long periods of time, causing changes like the Great oxidation event.": 0.8000000000000002,
#  "Earth's life has over time greatly diversified, allowing the biosphere to have different biomes, which are inhabited by comparatively similar plants and animals.": 0.3176470588235293,
#  'The different biomes developed at distinct elevations or water depths, planetary temperature latitudes and on land also with different humidity.': 0.6156862745098038,
#  "Earth's species diversity and biomass reaches a peak in shallow waters and with forests, particularly in equatorial, warm and humid conditions.": 0.21176470588235297,
#  'While freezing polar regions and high altitudes, or extremely arid areas are relatively barren of plant and animal life.': 0.3450980392156862,
#  'Earth provides liquid water—an environment where complex organic molecules can assemble and interact, and sufficient energy to sustain a metabolism.': 0.22745098039215683,
#  'Plants and other organisms take up nutrients from water, soils and the atmosphere.': 0.38823529411764707,
#  'These nutrients are constantly recycled between different species.': 0.07450980392156863,
#  "Extreme weather, such as tropical cyclones (including hurricanes and typhoons), occurs over most of Earth's surface and has a large impact on life in those areas.": 0.6,
#  'From 1980 to 2000, these events caused an average of 11,800 human deaths per year.': 0.21568627450980393,
#  'Many places are subject to earthquakes, landslides, tsunamis, volcanic eruptions, tornadoes, blizzards, floods, droughts, wildfires, and other calamities and disasters.': 0.15686274509803916,
#  'Human activities release greenhouse gases into the atmosphere which cause global warming.': 0.30980392156862746,
#  'In the 20th century Antarctica had been the last continent to see a first and until today limited human presence.': 0.16862745098039217,
#  'Most of the growth is expected to take place in sub-Saharan Africa.': 0.050980392156862744,
#  'Furthermore, since the 19th century humans have increasingly converged into urban areas with the majority living in urban areas by the 21st century.': 0.3176470588235294,
#  "Beyond Earth's surface humans have lived on a temporary basis, with only special purpose deep underground and underwater presence, and a few space stations.": 0.41960784313725474,
#  "Human population virtually completely remains on Earth's surface, fully depending on Earth and the environment it sustains.": 0.4156862745098039,
#  'Earth has been subject to extensive human settlement, and humans have developed diverse societies and cultures.': 0.18039215686274507,
#  'Most of these states together form the United Nations, the leading worldwide intergovernmental organization, which extends human governance over the ocean and Antarctica, and therefore all of Earth.': 0.34901960784313724,
#  'Earth has resources that have been exploited by humans.': 0.09019607843137255,
#  'Those termed non-renewable resources, such as fossil fuels, are only replenished over geological timescales.': 0.07058823529411765,
#  "Large deposits of fossil fuels are obtained from Earth's crust, consisting of coal, petroleum, and natural gas.": 0.3176470588235294,
#  'These deposits are used by humans both for energy production and as feedstock for chemical production.': 0.2313725490196078,
#  'Mineral ore bodies have also been formed within the crust through a process of ore genesis, resulting from actions of magmatism, erosion, and plate tectonics.': 0.5098039215686275,
#  'These metals and other elements are extracted by mining, a process which often brings environmental and health damage.': 0.09019607843137255,
#  "Earth's biosphere produces many useful biological products for humans, including food, wood, pharmaceuticals, oxygen, and the recycling of organic waste.": 0.27450980392156865,
#  'The land-based ecosystem depends upon topsoil and fresh water, and the oceanic ecosystem depends on dissolved nutrients washed down from the land.': 0.43921568627450974,
#  'Of the 12–14% of ice-free land that is used for croplands, 2 percentage points were irrigated in 2015.': 0.18039215686274512,
#  'Humans use building materials to construct shelters.': 0.08235294117647059,
#  "Human activities have impacted Earth's environments.": 0.09019607843137255,
#  "Through activities such as the burning of fossil fuels, humans have been increasing the amount of greenhouse gases in the atmosphere, altering Earth's energy budget and climate.": 0.5254901960784313,
#  'It is estimated that global temperatures in the year 2020 were 1.2 °C (2.2 °F) warmer than the preindustrial baseline.': 0.16470588235294115,
#  "The concept of planetary boundaries was introduced to quantify humanity's impact on Earth.": 0.12941176470588234,
#  'As of 2018, no country meets the basic needs of its population without transgressing planetary boundaries.': 0.12549019607843137,
#  'It is thought possible to provide all basic physical needs globally within sustainable levels of resource use.': 0.1764705882352941,
#  'Human cultures have developed many views of the planet.': 0.19607843137254902,
#  'The standard astronomical symbols of Earth are a quartered circle, , representing the four corners of the world, and a globus cruciger, .': 0.13725490196078427,
#  'Earth is sometimes personified as a deity.': 0.050980392156862744,
#  'In many cultures it is a mother goddess that is also the primary fertility deity.': 0.18039215686274512,
#  'Creation myths in many religions involve the creation of Earth by a supernatural deity or deities.': 0.10980392156862745,
#  "The Gaia hypothesis, developed in the mid-20th century, compared Earth's environments and life as a single self-regulating organism leading to broad stabilization of the conditions of habitability.": 0.33725490196078434,
#  "In particular, this caused a realization of the scope of effects from human activity on Earth's environment.": 0.1411764705882353,
#  "Enabled by science, particularly Earth observation, humans have started to take action on environmental issues globally, acknowledging the impact of humans and the interconnectedness of Earth's environments.": 0.2980392156862745,
#  "Scientific investigation has resulted in several culturally transformative shifts in people's view of the planet.": 0.13725490196078433,
#  'Initial belief in a flat Earth was gradually displaced in Ancient Greece by the idea of a spherical Earth, which was attributed to both the philosophers Pythagoras and Parmenides.': 0.09411764705882353,
#  "It was only during the 19th century that geologists realized Earth's age was at least many millions of years.": 0.3058823529411765}

# %% [markdown]
# ## Extracting the Article Summary

# %%
# Making the final summary
number_of_sentence_to_summarize_to = 10

import heapq #  Heap queue algorithm, uses priority queue algorithm
summary_sentences = heapq.nlargest(number_of_sentence_to_summarize_to, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)
print(summary)
# Out:
# 70.8% or 361.13 million km2 (139.43 million sq mi) of Earth's surface consists of the interconnected ocean, making it Earth's global ocean or world ocean. Solar System planets with considerable atmospheres do partly host atmospheric water vapor, but they lack surface conditions for stable surface water. Earth's polar regions currently retain most of all other water with large sheets of ice covering ocean and land, dwarfing Earth's groundwater, lakes, rivers and atmospheric water. Earth's surface topography consists mostly of the topography of the ocean surface and to a lesser extend of the terrain of Earth's crust above sea level. Regarding the surface distribution of land and water, Earth can be divided into an oceans-focused water hemisphere and a landmasses-focused land hemisphere.
